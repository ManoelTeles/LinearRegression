# %% [markdown]
# # Projeto Análise de Ecommerce
# ## analise da base de dados

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
ecommerce = pd.read_csv("Ecommerce.csv", delimiter=';')

# %%
ecommerce.head(1)
# Out:
#    ID da linha    ID do pedido Data do pedido Data de envio   Modo de envio  \
# 0        35615  US-2014-136189     2014-12-08    2014-12-12  Standard Class
#
#   Identificação do Cliente nome do client  Segmento    Cidade    Estado  ...  \
# 0                 DC-13285   Debra Catini  Consumer  Richmond  Virginia  ...
#
#    Categoria  Subcategoria            Nome do Produt Vendas Quantidade  \
# 0  Furniture   Furnishings  DAX Wood Document Frame.  82.38          6
#
#   Desconto  Lucro Frete  Prioridade de Encomenda       DiaSemana
# 0      0.0  25.54  6.56                    Medium  Segunda-Feira
#
# [1 rows x 25 columns]

# %%
for column_name in ecommerce.columns:
    print(column_name)
# Out:
# ID da linha
# ID do pedido
# Data do pedido
# Data de envio
# Modo de envio
# Identificação do Cliente
# nome do client
# Segmento
# Cidade
# Estado
# País
# Código postal
# Mercado
# Região
# ID do produto
# Categoria
# Subcategoria
# Nome do Produt
# Vendas
# Quantidade
# Desconto
# Lucro
# Frete
# Prioridade de Encomenda
# DiaSemana

# %%
ecommerce.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51290 entries, 0 to 51289
# Data columns (total 25 columns):
# ID da linha                 51290 non-null int64
# ID do pedido                51290 non-null object
# Data do pedido              51290 non-null object
# Data de envio               51290 non-null object
# Modo de envio               51290 non-null object
# Identificação do Cliente    51290 non-null object
# nome do client              51290 non-null object
# Segmento                    51290 non-null object
# Cidade                      51290 non-null object
# Estado                      51290 non-null object
# País                        51290 non-null object
# Código postal               9994 non-null float64
# Mercado                     51290 non-null object
# Região                      51290 non-null object
# ID do produto               51290 non-null object
# Categoria                   51290 non-null object
# Subcategoria                51290 non-null object
# ...

# %%
ecommerce.describe()
# Out:
#        ID da linha  Código postal        Vendas    Quantidade      Desconto  \
# count  51290.00000    9994.000000  51290.000000  51290.000000  51290.000000
# mean   25645.50000   55190.379428    246.490685      3.476545      0.142883
# std    14806.29199   32063.693350    487.565388      2.278766      0.212285
# min        1.00000    1040.000000      0.440000      1.000000      0.000000
# 25%    12823.25000   23223.000000     30.762500      2.000000      0.000000
# 50%    25645.50000   56430.500000     85.055000      3.000000      0.000000
# 75%    38467.75000   90008.000000    251.055000      5.000000      0.200000
# max    51290.00000   99301.000000  22638.480000     14.000000      0.850000
#
#               Lucro         Frete
# count  51290.000000  51290.000000
# mean      28.610968     26.375915
# std      174.341067     57.296804
# min    -6599.980000      0.000000
# 25%        0.000000      2.610000
# 50%        9.240000      7.790000
# 75%       36.810000     24.450000
# ...

# %% [markdown]
# ## Análise de dados exploratória

# %%
sns.set_palette("GnBu_d")
sns.set_style('whitegrid')

# %%
sns.pairplot(ecommerce)
# Out:
# /home/manoel/.local/lib/python3.7/site-packages/numpy/lib/histograms.py:829: RuntimeWarning: invalid value encountered in greater_equal
#   keep = (tmp_a >= first_edge)
# /home/manoel/.local/lib/python3.7/site-packages/numpy/lib/histograms.py:830: RuntimeWarning: invalid value encountered in less_equal
#   keep &= (tmp_a <= last_edge)
